# %%
# /// script
# requires-python = ">=3.12"
# dependencies = [
#     "requests>=2.33.1",
# ]
# ///
import os
import requests

def main():
    print(f'Hello, {os.path.expanduser("~")} from helloworld!')
    resp = requests.get('https://peps.python.org/api/peps.json')
    data = resp.json()
    print(f'Request response was: \n\n{data["1"]}\n')


if __name__ == "__main__":
    main()
# Out:
# Hello, /home/ebrosch from helloworld!
# Request response was:
#
# {'number': 1, 'title': 'PEP Purpose and Guidelines', 'authors': 'Barry Warsaw, Jeremy Hylton, David Goodger, Alyssa Coghlan', 'discussions_to': None, 'status': 'Active', 'type': 'Process', 'topic': '', 'created': '13-Jun-2000', 'python_version': None, 'post_history': '21-Mar-2001, 29-Jul-2002, 03-May-2003, 05-May-2012, 07-Apr-2013', 'resolution': None, 'requires': None, 'replaces': None, 'superseded_by': None, 'author_names': ['Barry Warsaw', 'Jeremy Hylton', 'David Goodger', 'Alyssa Coghlan'], 'url': 'https://peps.python.org/pep-0001/'}
